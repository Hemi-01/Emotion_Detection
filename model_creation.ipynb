# %% [markdown]
# # Emotion Detection

# %% [markdown]
# **Importing Libraries**

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline 

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image 
import tensorflow as tf 
print("Tensorflow version:", tf.__version__)
# Out:
# Tensorflow version: 2.13.0

# %% [markdown]
# **Exploring Dataset**

# %%
images=glob("train/**/**")
for i in range(9):
    image=random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# **Preparing Data for Training**

# %%
img_size=48
batch_size=64
datagen_train=ImageDataGenerator()
train_generator=datagen_train.flow_from_directory("train/",
                                                 target_size=(img_size,img_size),
                                                 color_mode="grayscale",
                                                 batch_size=batch_size,
                                                 class_mode="categorical",
                                                 shuffle=True)

datagen_validation=ImageDataGenerator()
validation_generator=datagen_train.flow_from_directory("test/",
                                                 target_size=(img_size,img_size),
                                                 color_mode="grayscale",
                                                 batch_size=batch_size,
                                                 class_mode="categorical",
                                                 shuffle=True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# **Defining Model**

# %%
def Convolution(input_tensor, filters, kernel_size):
    x=Conv2D(filters=filters, kernel_size=kernel_size, padding="same")(input_tensor)
    x=BatchNormalization()(x)
    x=Activation('relu')(x)
    x=MaxPooling2D(pool_size=(2,2))(x)
    x=Dropout(0.25)(x)
    
    return(x)

# %%
def Dense_f(input_tensor, nodes):
    x=Dense(nodes)(input_tensor)
    x=BatchNormalization()(x)
    x=Activation('relu')(x)
    x=Dropout(0.25)(x)
    
    return(x)

# %%
def model_fer(input_shape):
    inputs=Input(input_shape)
    conv_1=Convolution(inputs,32,(3,3))
    conv_2=Convolution(inputs,64,(5,5))
    conv_3=Convolution(inputs,128,(3,3))
    
    flatten=Flatten()(conv_3)
    
    dense_1=Dense_f(flatten,256)
    
    output=Dense(7,activation="softmax")(dense_1)
    model=Model(inputs=[inputs],outputs=[output])
    
    model.compile(loss=['categorical_crossentropy'],optimizer='adam',metrics=['accuracy'])
    
    return model

# %%
model=model_fer((48,48,1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       1280
#
#  batch_normalization_2 (Bat  (None, 48, 48, 128)       512
#  chNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 256)               18874624
#
#  batch_normalization_3 (Bat  (None, 256)               1024
#  chNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 18879239 (72.02 MB)
# Trainable params: 18878471 (72.02 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %% [markdown]
# **Initializing the Model**

# %%
epochs=15
steps_per_epoch=train_generator.n//train_generator.batch_size
validation_steps=validation_generator.n//validation_generator.batch_size

checkpoint=ModelCheckpoint("model_weight.h5",monitor='val_accuracy',save_weights_only=True,mode='max',verbose=1)
callbacks=[checkpoint]

# %% [markdown]
# # Training the Model

# %% [markdown]
# **The next cell takes time to complete**

# %%
history=model.fit(
    x=train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    callbacks=callbacks)
# Out:
# Epoch 1/15
# 448/448 [==============================] - ETA: 0s - loss: 1.6469 - accuracy: 0.3776
# Epoch 1: saving model to model_weight.h5
# 448/448 [==============================] - 1028s 2s/step - loss: 1.6469 - accuracy: 0.3776 - val_loss: 1.5184 - val_accuracy: 0.4011
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3554 - accuracy: 0.4866
# Epoch 2: saving model to model_weight.h5
# 448/448 [==============================] - 819s 2s/step - loss: 1.3554 - accuracy: 0.4866 - val_loss: 1.5392 - val_accuracy: 0.4163
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1917 - accuracy: 0.5521
# Epoch 3: saving model to model_weight.h5
# 448/448 [==============================] - 810s 2s/step - loss: 1.1917 - accuracy: 0.5521 - val_loss: 1.5984 - val_accuracy: 0.3584
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0597 - accuracy: 0.6081
# Epoch 4: saving model to model_weight.h5
# 448/448 [==============================] - 613s 1s/step - loss: 1.0597 - accuracy: 0.6081 - val_loss: 1.8559 - val_accuracy: 0.3270
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9302 - accuracy: 0.6593
# Epoch 5: saving model to model_weight.h5
# 448/448 [==============================] - 581s 1s/step - loss: 0.9302 - accuracy: 0.6593 - val_loss: 1.5080 - val_accuracy: 0.4442
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8057 - accuracy: 0.7078
# Epoch 6: saving model to model_weight.h5
# 448/448 [==============================] - 717s 2s/step - loss: 0.8057 - accuracy: 0.7078 - val_loss: 1.5837 - val_accuracy: 0.4316
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 0.6904 - accuracy: 0.7552
# Epoch 7: saving model to model_weight.h5
# 448/448 [==============================] - 666s 1s/step - loss: 0.6904 - accuracy: 0.7552 - val_loss: 1.5503 - val_accuracy: 0.4713
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5871 - accuracy: 0.7926
# Epoch 8: saving model to model_weight.h5
# 448/448 [==============================] - 583s 1s/step - loss: 0.5871 - accuracy: 0.7926 - val_loss: 1.7597 - val_accuracy: 0.4474
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5039 - accuracy: 0.8249
# Epoch 9: saving model to model_weight.h5
# 448/448 [==============================] - 666s 1s/step - loss: 0.5039 - accuracy: 0.8249 - val_loss: 1.9654 - val_accuracy: 0.4226
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.4346 - accuracy: 0.8513
# Epoch 10: saving model to model_weight.h5
# 448/448 [==============================] - 892s 2s/step - loss: 0.4346 - accuracy: 0.8513 - val_loss: 1.7057 - val_accuracy: 0.4867
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3765 - accuracy: 0.8720
# Epoch 11: saving model to model_weight.h5
# 448/448 [==============================] - 580s 1s/step - loss: 0.3765 - accuracy: 0.8720 - val_loss: 1.7630 - val_accuracy: 0.5040
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3215 - accuracy: 0.8939
# Epoch 12: saving model to model_weight.h5
# 448/448 [==============================] - 694s 2s/step - loss: 0.3215 - accuracy: 0.8939 - val_loss: 1.8168 - val_accuracy: 0.4898
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2994 - accuracy: 0.8985
# Epoch 13: saving model to model_weight.h5
# 448/448 [==============================] - 588s 1s/step - loss: 0.2994 - accuracy: 0.8985 - val_loss: 2.0400 - val_accuracy: 0.4784
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2677 - accuracy: 0.9117
# Epoch 14: saving model to model_weight.h5
# 448/448 [==============================] - 572s 1s/step - loss: 0.2677 - accuracy: 0.9117 - val_loss: 1.9142 - val_accuracy: 0.4837
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.9171
# Epoch 15: saving model to model_weight.h5
# 448/448 [==============================] - 693s 2s/step - loss: 0.2492 - accuracy: 0.9171 - val_loss: 1.9837 - val_accuracy: 0.4955

# %% [markdown]
# **Model Evaluation**

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 26s 214ms/step - loss: 1.9830 - accuracy: 0.4957
# [1.9829943180084229, 0.4956812560558319]

# %% [markdown]
# **Plotting Loss**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train','Validation'],loc='upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train','Validation'],loc='upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# **Saving Model**

# %%
model_json=model.to_json()
with open("model_a.json","w") as json_file:
    json_file.write(model_json)
